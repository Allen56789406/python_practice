# %%
import pandas as pd

# %%
import sqlite3

# %%
conn=sqlite3.connect('test.db')

# %%
head(conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 head(conn)
#
# NameError: name 'head' is not defined

# %%
url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
head(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 head(url)
#
# NameError: name 'head' is not defined

# %%
df=pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File D:\Apps\Application\python\Lib\urllib\request.py:1320, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319 try:
# -> 1320     h.request(req.get_method(), req.selector, req.data, headers,
#    1321               encode_chunked=req.has_header('Transfer-encoding'))
#    1322 except OSError as err: # timeout error
#
# File D:\Apps\Application\python\Lib\http\client.py:1386, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1385 """Send a complete request to the server."""
# -> 1386 self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Apps\Application\python\Lib\http\client.py:1432, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1431     body = _encode(body, 'body')
# ...

# %%
df=pd.read_csv(url)

# %%
df.to_sql('titanic',conn, if_exists='replace',index=False)
# Out:
# 891

# %%
pd.read_sql('SELECT Pclass, AVG(Age)  AS avg_age, COUNT(*) AS cny FROM titanic GROUP BY Pclass',conn)
# Out:
#    Pclass    avg_age  cny
# 0       1  38.233441  216
# 1       2  29.877630  184
# 2       3  25.140620  491

# %%
df.groupby('Pclass')['Age'].agg(['mean','count'])
# Out:
#              mean  count
# Pclass
# 1       38.233441    186
# 2       29.877630    173
# 3       25.140620    355

# %%
df1=pd.DataFrame({'id':[1,2,3],'name':['A','B','C']})

# %%
df2=pd.DataFrame({'id':[1,2,4],'score':[88,92,79]})

# %%
df2.to_sql('t2', conn, if_exists='replace', index=False)
# Out:
# 3

# %%
df1.to_sql('t1', conn, if_exists='replace', index=False)
# Out:
# 3

# %%
df1.to_sql('t1',conn,if_exists='replace',index=False)
# Out:
# 3

# %%
#SQL enquiry

# %%
pd.read_sql('SELECT * FROM t1 INNER JOIN t2 ON t1.id=t2.id', conn)
# Out:
#    id name  id  score
# 0   1    A   1     88
# 1   2    B   2     92

# %%
pd.read_sql('SELECT * FROM t1 LEfT JOIN t2 ON t1.id=t2.id', conn)
# Out:
#    id name   id  score
# 0   1    A  1.0   88.0
# 1   2    B  2.0   92.0
# 2   3    C  NaN    NaN

# %%
# PANDAS

# %%
pd.merge(df1,df2, on='id',how='inner')
# Out:
#    id name  score
# 0   1    A     88
# 1   2    B     92

# %%
pd.merge(df1,df2,on='id',how='left')
# Out:
#    id name  score
# 0   1    A   88.0
# 1   2    B   92.0
# 2   3    C    NaN

# %%
# SQL_CASE WHEN

# %%
pd.read_sql('''
SELECT name,
  CASE WHEN score >= 90 THEN 'high'
       WHEN score >= 80 THEN 'mid'
       ELSE 'low' END AS level
FROM t2
''', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File D:\Apps\Application\python\Lib\site-packages\pandas\io\sql.py:2745, in SQLiteDatabase.execute(self, sql, params)
#    2744 try:
# -> 2745     cur.execute(sql, *args)
#    2746     return cur
#
# OperationalError: no such column: name
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pd.read_sql('''
#       2 SELECT name,
#       3   CASE WHEN score >= 90 THEN 'high'
#       4        WHEN score >= 80 THEN 'mid'
#
# File D:\Apps\Application\python\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
df2['level']=pd.cut(df2['score'], bins=[0, 80, 90, 100], labels =['low','mid','high'])
